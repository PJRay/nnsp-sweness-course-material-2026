# %% [markdown]
# # Simulation quiz: Ni single crystal in a Triple Axis Spectrometer (L13)
#
# *Run all cells (menu Run > Run All Cells) to display the answer fields and the Check buttons.*

# %%
from quiz_widgets import load, question
load("quiz_data.json")

# %% [markdown]
# In this exercise you will consider the main aspects related to planning and carrying out a spectroscopic neutron experiment through this virtual experiment [https://sim.e-neutrons.esss.dk/instrument/swedness/Ni_TAS](https://sim.e-neutrons.esss.dk/instrument/swedness/Ni_TAS) with a single crystal on a triple axis spectrometer. Select the **Ni_TAS** instrument file in the McStas application on the virtual desktop.
#
# You will measure both elastic Bragg scattering and inelastic phonon scattering of the neutron and evaluate your data.

# %% [markdown]
# ## Question 1
#
# Connect a particular neutron scattering vector $\mathbf{q}=(qh,qk,ql)$ to a distance $d$ between lattice planes which may Bragg scatter the neutron. Use the lattice parameter of fcc Ni $a=3.52$ Å.

# %%
question(1)

# %% [markdown]
# ## Question 2
#
# When planning the instrument setup for a particular experiment one first needs to consider which part of the reciprocal space of the crystal needs to be mapped i.e. which q-values should be scanned.
#
# The smallest d-spacing you would like to scan sets a requirement on the incoming wavelength which can be found from Bragg's law. Choose the right requirement
#
# Select one:

# %%
question(2)

# %% [markdown]
# ## Question 3
#
# Calculate the energy $E_{min}$ in units of meV which corresponds to $\lambda_{max}=1.011$ Å.

# %%
question(3)

# %% [markdown]
# ## Question 4
#
# If you want to measure elastically scattered neutrons, you should in your instrument set the following condition on the incoming energy $E_i$ and outgoing energy $E_f$ of the neutron:
#
# Select one:

# %%
question(4)

# %% [markdown]
# ## Question 5
#
# Now open [the virtual TAS](https://sim.e-neutrons.esss.dk/instrument/swedness/Ni_TAS) and notice that we have chosen to place the sample so that the [reciprocal lattice](https://e-learning.pan-training.eu/mod/url/view.php?id=3066) vectors $\mathbf{\tau}=(110)$ and $\mathbf{\tau}=(001)$ are in the scattering plane, meaning that the neutron scattering vector $\mathbf{q}$ lies in the plane spanned by the two lattice vectors.
#
# Identify the variables in the virtual TAS: Drag the crosshair of the marker to the instrument variale which the maker label describes best.

# %%
question(5)

# %% [markdown]
# ## Question 6
#
# Open the virtual TAS instrument and set all required parameters to measure elastically (Bragg) scattered neutrons from the [reciprocal lattice](https://e-learning.pan-training.eu/mod/url/view.php?id=3066) point $\mathbf{\tau}=(004)$ in Ni. Use $E_i=80$ meV and simulate 1 million neutron rays from the source.
#
# The simulation shows output from the detector. Both the intensity in units of cts/s, the statistical error on the intensity and the number of simulated rays which reaches the detector are shown at the top of the plot.
#
# What is the total intensity of neutrons on the detector? State your answer with two significant digits in units of cts/s.

# %%
question(6)

# %% [markdown]
# ## Question 7
#
# Use $E_i = E_f= 80$ meV in your simulation and scan QL =3.8,4.2 while keeping QHK=0 to obtain a Bragg peak centered on the (004) position. For each scan point the intensity on the detector is shown as a single point with error on the data plot.
#
# What is the ratio between the peak intensity and the background? (Remember the intensity is plotted in 10'th logarithm)
#
# Remember to specify the number of scan steps to successfully scan the parameter!

# %%
question(7)

# %% [markdown]
# ## Question 8
#
# Now you want to measure a specific phonon, say the longitudinal $[00\xi]_L$ phonon. If you are in doubt what that is you should solve the quiz "Phonons in Ni" before proceeding.
#
# Which input parameter settings should you use for the scattering vector $\mathbf{q}$? Drag and drop the right values of the parameters.

# %%
question(8)

# %% [markdown]
# ## Question 9
#
# In order to measure the phonon you need to set the instrument analyser so it only picks up neutrons which have lost a certain amount of energy, say $\Delta E =20$ meV.
#
# Assume that you still have incoming neutron energy $E_i=80$ meV on the sample. What should you set the energy of the outgoing neutrons from the sample (selected by the analyser) $E_f$ to be?
#
# State your answer with 2 significant digits in units of meV.

# %%
question(9)

# %% [markdown]
# ## Question 10
#
# Perform the appropriate scan with the [virtual TAS instrument](https://sim.e-neutrons.esss.dk/instrument/swedness/Ni_TAS) to measure the $[00\xi]_L$ phonon close to (004) by setting QHK=0 and QL=$3.3,4.7$. Set an appropriate amount (less than 50) of scan steps in order to describe the features in your data:
#
# Select one:

# %%
question(10)

# %% [markdown]
# ## Question 11
#
# ![tas phonon scan](tas_phonon_scan.png)
#
# When you do a q-scan which crosses a phonon branch twice (as you just did), you often see a similar intensity pattern as the one above.
#
# Why do you think one peak is wider than the other?
#
# Select one:

# %%
question(11)

# %% [markdown]
# ## Question 12
#
# Assume that the longitudinal acoustic phonon (along $(00\xi)$) in Ni which you have just measured (and data is plotted in the previous question) is linearly dispersing between energies of 0 and 20 meV.
#
# From the position of the peaks in your scan before (data also plotted int he previous question) calculate the velocity of sound (along $(00\xi)$) in Ni. State your answer in units of [meV*Å]

# %%
question(12)

# %% [markdown]
# Please report in the "Forum for error report" found on the frontpage any errors, typos, inconsistencies that you have found in this quiz. It could be a particular hint or question you liked, a particular place where we should add/revise a hint or explanation or any errors, inconsistencies and typos.
#
# Also, feel free to comment on the pedagogical sides: Is it too easy, too hard, too difficult to understand? Where could we have placed a hint to help you move on?
#
# Thank you

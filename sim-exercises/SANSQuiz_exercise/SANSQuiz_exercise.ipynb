# %% [markdown]
# # Simulation quiz: Small Angle Neutron Scattering (L11)
#
# *Run all cells (menu Run > Run All Cells) to display the answer fields and the Check buttons.*

# %%
from quiz_widgets import load, question
load("quiz_data.json")

# %% [markdown]
# To answer the questions In this quiz you will perform several virtual Small Angle Neutron Scattering (SANS) experiments on samples which are hard, dilute spheres in solution. You can perform the virtual experiments selecting the **SANSsimple** instrument file in the McStas application on the virtual desktop and varying the input parameters.
#
# Depending on your answer, you will get different kinds of feedback - even if the answer is correct.You can follow your progress in the top right corner. You can check your answer each time you give it.
#
# Enjoy!

# %% [markdown]
# ## Question 1
#
# Run the simulation with default parameters or another set of parameters that you like.
#
# You should get a web-page with images that look like the first row of images below. By pressing L, you can get different images. We want you to find out what the different images on the web page represent. We encourage you to play around and click on the page (not the image below).
#
# Below the following image, you will find text codes that you can drag onto an area on the image. Each code corresponds to a description of the area on the image:
#
# POI: A plot of the image at the detector
#
# LPOI: A log-plot of the image at the detector
#
# RSI: A graph of the intensity measured at the detector in real space.
#
# LRSI: A log scale graph of the intensity measured at the detector in real space.
#
# ISI: A graph of the intensity measured at the detector in reciprocal space.
#
# LISI: A log scale graph of the intensity measured at the detector in reciprocal space.
#
# *When you are ready, drag and drop the text boxes to the appropriate places on the image.*

# %%
question(1)

# %% [markdown]
# ## Question 2
#
# ![sans Ir plot](sans_Ir_plot.png)
#
# The image shows a logarithmic plot of the intensity as a function of radius for the default configuration of the simulation with the *following changes*:
#
# The samples are spheres with a radius of 200 Å (no uncertainty) and the uncertainty on the neutron wave length is set to $10^{-3}$ Å (very small).
#
# Run the virtual experiment to find out, which of the following statements about the $I(r)$ graph are true.
#
# Select one or more:

# %%
question(2)

# %% [markdown]
# ## Question 3
#
# ![sans instrument layout zx](sans_instrument_layout_zx.png)
#
# The image shows a schematic layout of the SANSsimple experimental setup. The detector is the dark grey vertical line segment on the right at $Z=9m$ in this particular case.
#
# Use the geometry of the setup and your knowledge about scattering to derive an expression for the radius at which a scattered neutron is detected, given the scattering angle, $2\theta$, and the distance to the detector, $d$.
#
# Answer

# %%
question(3)

# %% [markdown]
# ## Question 4
#
# Now, we want you to derive a relation between reciprocal space and real space for the SANS setup. You can do this by comparing the relation you just found between scattering angle and radius with the expression for [the length of the q-vector](https://pan-learning.org/wiki/index.php/Basics_of_neutron_scattering#label-fig:theta_2theta).
#
# Use your result to answer the following question:
#
# A monocromatic ray of neutrons with a wavelength of $\lambda$ [Å] is aimed at a sample. The sample is at a distance d [m] from the detector. What is the corresponding q-value for neutrons detected at a distance r [m] from the center?
#
# Answer

# %%
question(4)

# %% [markdown]
# ## Question 5
#
# $I(q)$-plots (reciprocal space plots) are usually preferred to $I(r)$-plots (real space plots) in neutron scattering. Below you will find three different explanations to why that is. Which ones are correct?
#
# Select one or more:

# %%
question(5)

# %% [markdown]
# Now, we want you to explore some of the physics of SANS: scattering of spheres, by using the online simulation from before. While the questions below are aimed at guiding your investigations, feel free to use the online simulation to investigate other aspects later on.

# %% [markdown]
# ## Question 6
#
# First make sure to select a sample with 100 Å hard spheres by setting parameters R=100 in your instrument.
#
# Now vary the neutron wavelength $\lambda$ and the wavelength spread $\Delta \lambda$ and notice the effect on the $I(q)$ detector. Select the choice which decribes best what happens:

# %%
question(6)

# %% [markdown]
# ## Question 7
#
# Now, imagine that you have a series of hard sphere samples with different radii which you measure with neutrons of wavelegth 10 Å. Simulate this and select the description that fits your observations best:

# %%
question(7)

# %% [markdown]
# Please report in the "Forum for error report" found on the frontpage any errors, typos, inconsistencies that you have found in this quiz. It could be a particular hint or question you liked, a particular place where we should add/revise a hint or explanation or any errors, inconsistencies and typos.
#
# Also, feel free to comment on the pedagogical sides: Is it too easy, too hard, too difficult to understand? Where could we have placed a hint to help you move on?
#
# Thank you
